# %%
import requests
import pandas as pd
from tqdm.notebook import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed

def get_cutout(outfile, pos, size=30, low=False, dr3=False, verbose=False, auth=None):
    """
    Get a cutout at position pos with size size arcmin. Save the FITS file to outfile.
    """
    base = 'dr3' if dr3 else 'dr2'
    url = 'https://lofar-surveys.org/'
    page = base + '-low-cutout.fits' if low else base + '-cutout.fits'
    full_url = url + page

    if verbose:
        print(f"Trying {full_url} with params={{'pos': {pos}, 'size': {size}}}")
    response = requests.get(full_url, params={'pos': pos, 'size': size}, auth=auth, stream=True)
    
    if verbose:
        print(f"Received response code {response.status_code}")
    if response.status_code != 200:
        raise RuntimeError(f"Status code {response.status_code} returned")
    if response.headers.get('content-type') != 'application/fits':
        raise RuntimeError("Server did not return a FITS file, possibly no coverage for this area")

    with open(outfile, 'wb') as f:
        f.write(response.content)

def download_worker(index, row, size, low, dr3, verbose, auth):
    """
    Worker function to download a single cutout and return status.
    """
    ra = row['RA (degrees)']
    dec = row['Dec (degrees)']
    pos = f"{ra},{dec}"
    outfile = f"cutout_{index}.fits"
    base = 'dr3' if dr3 else 'dr2'
    url = 'https://lofar-surveys.org/'
    page = base + '-low-cutout.fits' if low else base + '-cutout.fits'
    full_url = url + page

    try:
        get_cutout(outfile, pos, size=size, low=low, dr3=dr3, verbose=verbose, auth=auth)
        return index, full_url, None  # Success
    except Exception as e:
        return index, None, str(e)  # Failure

# %%
def process_excel_multithreaded(input_file, output_file, size=30, low=False, dr3=False, verbose=False, auth=None, max_workers=5):
    """
    Read RA and Dec from an Excel file, download FITS files in parallel, and update the file with links.
    """
    df = pd.read_excel(input_file)
    if 'RA (degrees)' not in df.columns or 'Dec (degrees)' not in df.columns:
        raise ValueError("The input Excel file must have 'Ra (degrees)' and 'Dec (degrees)' columns.")
    
    # Prepare for multithreading
    df['Download Link'] = ''
    futures = []

    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        for index, row in df.iterrows():
            futures.append(executor.submit(download_worker, index, row, size, low, dr3, verbose, auth))
        
        for future in tqdm(as_completed(futures), total=len(futures), desc="Downloading files"):
            index, link, error = future.result()
            if link:
                df.at[index, 'Download Link'] = link
            elif error:
                print(f"Failed to download row {index}: {error}")

    # Save updated DataFrame back to Excel
    df.to_excel(output_file, index=False)
    print(f"Updated Excel file saved to {output_file}")

# %%
input_file = "coordinates.xlsx"  # Path to input Excel file
output_file = "output_file.xlsx"  # Path to save updated Excel file

# %%
process_excel_multithreaded(input_file, output_file, size=30, low=True, max_workers=10)
# Out:
# Downloading files:   0%|          | 0/22000 [00:00<?, ?it/s]
# Failed to download row 4: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 9: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 3: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 5: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 8: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 1: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 2: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 6: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 10: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 12: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 11: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 17: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 14: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 13: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 23: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 18: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 22: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 24: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 25: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 21: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 20: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 26: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 19: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 27: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 31: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 32: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 29: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 33: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 30: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 34: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 28: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 36: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 35: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 39: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 40: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 41: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 38: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 43: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 42: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 44: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 45: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 46: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 47: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 49: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 48: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 51: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 54: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 53: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 55: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 50: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 56: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 59: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 58: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 57: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 60: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 61: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 62: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 63: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 64: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 66: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 67: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 65: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 69: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 70: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 71: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 74: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 68: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 72: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 73: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 75: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 77: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 78: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 76: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 82: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 83: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 80: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 84: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 85: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 81: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 86: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 89: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 87: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 93: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 91: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 94: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 95: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 96: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 97: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 98: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 99: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 101: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 104: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 105: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 102: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 107: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 106: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 109: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 108: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 111: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 112: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 113: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 115: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 116: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 118: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 122: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 121: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 124: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 123: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 127: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 128: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 126: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 129: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 130: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 131: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 132: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 133: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 134: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 136: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 137: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 138: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 135: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 140: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 141: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 144: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 145: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 143: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 146: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 149: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 150: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 151: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 153: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 152: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 155: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 154: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 158: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 157: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 156: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 159: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 160: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 161: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 163: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 164: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 162: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 166: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 165: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 167: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 168: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 169: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 170: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 171: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 172: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 173: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 174: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 175: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 176: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 177: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 178: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 179: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 180: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 181: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 183: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 185: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 182: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 184: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 186: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 187: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 190: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 188: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 192: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 194: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 195: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 198: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 200: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 199: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 197: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 201: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 202: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 204: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 203: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 207: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 208: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 209: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 210: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 212: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 213: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 215: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 216: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 217: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 218: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 220: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 221: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 222: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 223: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 224: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 225: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 226: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 227: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 228: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 229: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 230: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 231: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 232: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 233: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 234: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 237: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 238: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 235: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 239: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 240: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 241: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 243: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 244: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 242: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 245: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 246: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 247: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 248: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 250: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 251: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 254: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 253: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 252: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 256: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 258: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 255: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 260: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 259: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 257: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 261: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 262: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 263: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 265: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 266: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 264: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 267: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 271: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 269: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 270: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 268: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 272: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 276: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 277: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 274: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 275: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 273: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 283: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 281: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 280: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 282: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 278: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 284: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 285: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 286: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 287: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 288: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 290: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 289: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 291: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 294: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 295: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 296: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 297: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 298: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 300: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 299: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 301: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 302: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 303: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 305: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 304: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 306: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 307: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 308: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 309: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 311: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 312: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 313: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 314: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 310: Status code 500 returned
# Failed to download row 318: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 316: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 319: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 317: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 321: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 323: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 322: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 324: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 325: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 326: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 327: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 328: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 329: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 333: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 330: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 332: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 331: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 334: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 336: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 337: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 338: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 340: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 339: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 341: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 343: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 345: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 344: Status code 500 returned
# Failed to download row 349: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 348: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 351: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 352: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 353: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 355: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 356: Status code 500 returned
# Failed to download row 357: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 359: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 358: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 360: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 361: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 363: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 362: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 364: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 365: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 366: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 367: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 368: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 370: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 369: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 371: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 375: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 374: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 378: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 381: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 382: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 383: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 384: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 385: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 386: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 388: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 387: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 389: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 390: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 392: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 391: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 393: Server did not return a FITS file, possibly no coverage for this area
# Failed to download row 394: Server did not return a FITS file, possibly no coverage for this area
